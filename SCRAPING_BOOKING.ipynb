# %%
# !pip install scrapy
# Out:
# ...
#   Using cached Scrapy-2.5.1-py2.py3-none-any.whl (254 kB)
# ...
#   Using cached Twisted-21.7.0-py3-none-any.whl (3.1 MB)
# ...
#   Using cached service_identity-21.1.0-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached parsel-1.6.0-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Processing /home/jovyan/.cache/pip/wheels/d1/d7/61/11b5b370ee487d38b5408ecb7e0257db9107fa622412cbe2ff/PyDispatcher-2.0.5-py3-none-any.whl
# ...
#   Using cached zope.interface-5.4.0-cp38-cp38-manylinux2010_x86_64.whl (259 kB)
# ...
#   Using cached itemadapter-0.4.0-py3-none-any.whl (10 kB)
# ...
#   Using cached h2-3.2.0-py2.py3-none-any.whl (65 kB)
# ...
# Processing /home/jovyan/.cache/pip/wheels/91/64/36/bd0d11306cb22a78c7f53d603c7eb74ebb6c211703bc40b686/Protego-0.1.16-py3-none-any.whl
# ...
#   Using cached lxml-4.6.3-cp38-cp38-manylinux2014_x86_64.whl (6.8 MB)
# ...
#   Using cached cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# ...

# %%
import scrapy
import scrapy
from scrapy.crawler import CrawlerProcess
import os 
import logging

# %%
# Creating our Booking Spider class
class BookingSpider(scrapy.Spider):
    name = "booking"
    #URLs of our 5 cities
    start_urls = ['https://www.booking.com/searchresults.fr.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQ24ARnIAQzYAQHoAQH4AQuIAgGoAgO4AtqckYsGwAIB0gIkNWVlZWJmYjQtYjUwYy00ODM2LTljNzYtOThjNDUwNjcyMWNh2AIG4AIB&sid=a5563585aba528508c52ed40193e9101&aid=304142&sb=1&sb_lp=1&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQ24ARnIAQzYAQHoAQH4AQuIAgGoAgO4AtqckYsGwAIB0gIkNWVlZWJmYjQtYjUwYy00ODM2LTljNzYtOThjNDUwNjcyMWNh2AIG4AIB%3Bsid%3Da5563585aba528508c52ed40193e9101%3Bsb_price_type%3Dtotal%26%3B&ss=Collioure%2C+Languedoc-Roussillon%2C+France&is_ski_area=&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&search_pageview_id=4be667edaa220066&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-1421032&dest_type=city&place_id_lat=42.524529&place_id_lon=3.082255&search_pageview_id=4be667edaa220066&search_selected=true&ss_raw=Collioure&order=bayesian_review_score',
fsearchresults.fr.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQ24ARnIAQzYAQHoAQH4AQuIAgGoAgO4AtqckYsGwAIB0gIkNWVlZWJmYjQtYjUwYy00ODM2LTljNzYtOThjNDUwNjcyMWNh2AIG4AIB%3Bsid%3Da5563585aba528508c52ed40193e9101%3Btmpl%3Dsearchresults%3Bclass_interval%3D1%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsearch_pageview_id%3D4be667edaa220066%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dindex%3Bsrc_elem%3Dsb%3Bsrpvid%3Da794685139ff0035%3Bss%3DFoix%3Bss_all%3D0%3Bss_raw%3DFoix%3Bssb%3Dempty%3Bsshis%3D0%3Btop_ufis%3D1%26%3B&ss=Cassis%2C+Provence-Alpes-C%C3%B4te+d%27Azur%2C+France&is_ski_area=0&ssne=Foix&ssne_untouched=Foix&city=-1427188&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&sb_changed_group=1&from_sf=1&sb_with_order=1&order=bayesian_review_score&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-1416912&dest_type=city&place_id_lat=43.21513&place_id_lon=5.53712&search_pageview_id=a794685139ff0035&search_selected=true&ss_raw=Cassi',
                  'https://www.booking.com/searchresults.fr.html?label=gen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQ24ARnIAQzYAQHoAQH4AQuIAgGoAgO4ArqrposGwAIB0gIkMjkwOWEzNzktNzk1ZS00NzM4LWFjZjEtMDBhMGJiOGVmMmNl2AIG4AIB&sid=060b5b041c4dbf7eda7023a6d5ea85d2&aid=304142&sb=1&sb_lp=1&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Findex.fr.html%3Flabel%3Dgen173nr-1FCAEoggI46AdIM1gEaE2IAQGYAQ24ARnIAQzYAQHoAQH4AQuIAgGoAgO4ArqrposGwAIB0gIkMjkwOWEzNzktNzk1ZS00NzM4LWFjZjEtMDBhMGJiOGVmMmNl2AIG4AIB%3Bsid%3D060b5b041c4dbf7eda7023a6d5ea85d2%3Bsb_price_type%3Dtotal%26%3B&ss=Aix-en-Provence%2C%20Provence-Alpes-C%C3%B4te%20d%27Azur%2C%20France&is_ski_area=&checkin_year=&checkin_month=&checkout_year=&checkout_month=&group_adults=2&group_children=0&no_rooms=1&b_h4u_keep_filters=&from_sf=1&ss_raw=aix&ac_position=0&ac_langcode=fr&ac_click_type=b&dest_id=-1406939&dest_type=city&place_id_lat=43.526314&place_id_lon=5.445464&search_pageview_id=c84b689d26d101a5&search_pageview_id=c84b689d26d101a5&search_selected=true&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=0&order=bayesian_review_score'
                 ]
                  
    
    def parse(self, response):
      
        rep = response.css('div.sr_property_block_main_row')
        
        for r in rep:
            yield { 
                # Scraping every information we need from booking
                'city_name' : r.css('a.bui-link::text').get().strip(),
                'hotel_name': r.css('span.sr-hotel__name::text').get(),
                'hotel_url' : "https://www.booking.com"+r.css('div.sr-hotel__title-wrap a::attr(href)').get().strip(),
                'hotel_coord' : r.css('div.sr_card_address_line a::attr(data-coords)').get(),
                'hotel_score': r.css('div.bui-review-score__badge::text').get().strip(),
                'hotel_text': r.css('div.hotel_desc::text').get()
                
            }

# %%
# Name of the file where the results will be saved
filename = "scrapy_booking_list.json"

# If file already exists, delete it before crawling (because Scrapy will concatenate the last and new results otherwise)
if filename in os.listdir('scraping'):
        os.remove('scraping' + filename)

# Declare a new CrawlerProcess with some settings
process = CrawlerProcess(settings = {
    'USER_AGENT': 'Mozilla/5.0 (X11; CrOS x86_64 14092.57.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.85 Safari/537.36',
    'LOG_LEVEL': logging.INFO,
    "FEEDS": {
        'scraping' + filename : {"format": "json"},
    }
})

# Start the crawling using the spider you defined above
process.crawl(BookingSpider)
process.start()
# Out:
# 2021-10-16 19:02:28 [scrapy.utils.log] INFO: Scrapy 2.5.1 started (bot: scrapybot)
# 2021-10-16 19:02:28 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 21.7.0, Python 3.8.6 | packaged by conda-forge | (default, Oct  7 2020, 19:08:05) - [GCC 7.5.0], pyOpenSSL 19.1.0 (OpenSSL 1.1.1h  22 Sep 2020), cryptography 3.1.1, Platform Linux-5.4.129+-x86_64-with-glibc2.10
# 2021-10-16 19:02:28 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 20,
#  'USER_AGENT': 'Mozilla/5.0 (X11; CrOS x86_64 14092.57.0) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/93.0.4577.85 Safari/537.36'}
# 2021-10-16 19:02:28 [scrapy.extensions.telnet] INFO: Telnet Password: 45bc6fe06c29e764
# 2021-10-16 19:02:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
# ...

# %%
import pandas as pd

#ouvrir csv de scraping en dataframe, pd .read json
#nettoyage espaces etc ...
#remettre en csv après nettoyage
#ouvrir données météo et merger avec dans un nouveau csv
#fini !!!!!!!! ah non il reste la viz
#rappel csv mergé et faire viz map
#sortir lat et long de leur liste et refaire colonne pour faire map avec un point par hotel

# %%
import pandas as pd
#scrap_112 = pd.read_json('scrapingscrapy_booking_list.json')
